# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import data

# %%
hos_rate_age_sex_df = pd.read_csv("scenario_b_data/Hospital Admission Rate by Age and Sex.csv")
hos_rate_age_sex_df
# Out:
#      year      facility_type_a     sex              age   rate
# 0    2009                Acute    Male       0-14 Years  100.1
# 1    2009                Acute    Male      15-64 years   62.7
# 2    2009                Acute    Male  65 years & over  323.0
# 3    2009                Acute  Female       0-14 Years   84.9
# 4    2009                Acute  Female      15-64 years   73.5
# ..    ...                  ...     ...              ...    ...
# 211  2020  Community Hospitals    Male      15-64 years    1.4
# 212  2020  Community Hospitals    Male  65 years & over   22.8
# 213  2020  Community Hospitals  Female       0-14 Years    0.0
# 214  2020  Community Hospitals  Female      15-64 years    1.0
# 215  2020  Community Hospitals  Female  65 years & over   22.5
#
# [216 rows x 5 columns]

# %%
hos_rate_sex_df = pd.read_csv("scenario_b_data/Hospital Admission Rate by Sex.csv")
hos_rate_sex_df
# Out:
#     year        facility_type_a     sex   rate
# 0   2009                  Acute    Male   90.2
# 1   2009                  Acute  Female   96.4
# 2   2009  Psychiatric Hospitals    Male    2.7
# 3   2009  Psychiatric Hospitals  Female    1.6
# 4   2009    Community Hospitals    Male    1.5
# ..   ...                    ...     ...    ...
# 67  2020                  Acute  Female  116.3
# 68  2020  Psychiatric Hospitals    Male    2.3
# 69  2020  Psychiatric Hospitals  Female    1.4
# 70  2020    Community Hospitals    Male    4.3
# 71  2020    Community Hospitals  Female    4.3
#
# [72 rows x 4 columns]

# %%
population_sheets = pd.read_excel("scenario_b_data/respopagesextod2000to2020e.xlsx", sheet_name=None, skiprows=2)
population_sheets.keys()
# Out:
# dict_keys(['2020(Total)', '2020(Male)', '2020(Female)', '2011-2019(Total)', '2011-2019(Male)', '2011-2019(Female)', '2001-2010(Total)', '2001-2010(Male)', '2001-2010(Female)', '2000(Total)', '2000(Male)', '2000(Female)'])

# %%
birth_fertility_df = pd.read_csv("scenario_b_data/M810091-table.csv", skiprows=9, nrows=17)
birth_fertility_df
# Out:
#                                   Data Series     2023      2022      2021   \
# 0           Total Fertility Rate (Per Female)      0.97      1.04      1.12
# 1        15 - 19 Years (Per Thousand Females)      2.20      2.10      2.20
# 2        20 - 24 Years (Per Thousand Females)     10.60     11.20     11.70
# 3        25 - 29 Years (Per Thousand Females)     43.70     48.80     53.40
# 4        30 - 34 Years (Per Thousand Females)     78.70     86.70     92.90
# 5        35 - 39 Years (Per Thousand Females)     47.90     49.40     53.60
# 6        40 - 44 Years (Per Thousand Females)      9.60      9.80     10.20
# 7        45 - 49 Years (Per Thousand Females)      0.60      0.40      0.30
# 8                        Chinese (Per Female)      0.81      0.87      0.96
# 9                         Malays (Per Female)      1.65      1.83      1.82
# 10                       Indians (Per Female)      0.95      1.01      1.05
# ...

# %%
death_life_df = pd.read_csv("scenario_b_data/M810481.csv", skiprows=9, nrows=13)
death_life_df
# Out:
#                                           Data Series    2023     2022   \
# 0          Crude Death Rate (Per Thousand Residents )      6.2      6.3
# 1   Infant Mortality Rate (Per Thousand Resident L...      2.2      1.8
# 2   Infant Mortality Rate - Males (Per Thousand Re...      1.9      1.9
# 3   Infant Mortality Rate - Females (Per Thousand ...      2.6      1.6
# 4   Neonatal Mortality Rate (Per Thousand Resident...      1.1      1.1
# 5   Perinatal Mortality Rate (Per Thousand Live-Bi...      5.2      3.9
# 6   Maternal Mortality Ratio (Per Hundred Thousand...      3.0      2.8
# 7   Under-5 Mortality Rate (Per Thousand Resident ...      2.5      2.3
# 8   Under-5 Mortality Rate - Males (Per Thousand R...      2.5      2.3
# 9   Under-5 Mortality Rate - Females (Per Thousand...      2.4      2.4
# 10  Age-Standardised Death Rate (Per Thousand Resi...      5.6      5.9
# 11                              Total Deaths (Number)  26888.0  26891.0
# ...
